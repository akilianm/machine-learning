# %%
# Install Packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Import data
data= 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-03-churn-prediction/WA_Fn-UseC_-Telco-Customer-Churn.csv'
# !wget $data -O data-week-3.csv

df = pd.read_csv('data-week-3.csv')
# Out:
# --2026-04-09 20:34:10--  https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-03-churn-prediction/WA_Fn-UseC_-Telco-Customer-Churn.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response...
# 200 OK
# Length: 977501 (955K) [text/plain]
# Saving to: ‘data-week-3.csv’
#
# data-week-3.csv     100%[===================>] 954.59K  --.-KB/s    in 0.01s
#
# 2026-04-09 20:34:10 (76.7 MB/s) - ‘data-week-3.csv’ saved [977501/977501]

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.T
# Out:
#                               0             1               2     \
# customerID              7590-VHVEG    5575-GNVDE      3668-QPYBK
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# ...

# %%
# Made column names consistent
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn'],
#       dtype='str')

# %%
# Made categorical column values consistent
categorical_columns =list(df.dtypes[df.dtypes == 'str'].index)

for col in categorical_columns:
    df[col]= df[col].str.lower().str.replace(' ', '_')
    
df.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  7590-vhveg  female              0     yes         no       1           no
# 1  5575-gnvde    male              0      no         no      34          yes
# 2  3668-qpybk    male              0      no         no       2          yes
# 3  7795-cfocw    male              0      no         no      45           no
# 4  9237-hqitu  female              0      no         no       2          yes
#
#       multiplelines internetservice onlinesecurity  ... deviceprotection  \
# 0  no_phone_service             dsl             no  ...               no
# 1                no             dsl            yes  ...              yes
# 2                no             dsl            yes  ...               no
# 3  no_phone_service             dsl            yes  ...              yes
# 4                no     fiber_optic             no  ...               no
#
# ...

# %%
df.dtypes
# Out:
# customerid              str
# gender                  str
# seniorcitizen         int64
# partner                 str
# dependents              str
# tenure                int64
# phoneservice            str
# multiplelines           str
# internetservice         str
# onlinesecurity          str
# onlinebackup            str
# deviceprotection        str
# techsupport             str
# streamingtv             str
# streamingmovies         str
# contract                str
# paperlessbilling        str
# paymentmethod           str
# monthlycharges      float64
# totalcharges            str
# churn                   str
# dtype: object

# %%
# This column should be numeric
df.totalcharges
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: totalcharges, Length: 7043, dtype: str

# %%
# Changed it to numeric
pd.to_numeric(df.totalcharges, errors= 'coerce')
df['totalcharges'] = pd.to_numeric(df.totalcharges, errors= 'coerce')

# Replaced null values with 0
df['totalcharges'].isnull().sum()

df.totalcharges =df.totalcharges.fillna(0)

# %%
# changed churn from 'yes' 'no' to 1 and 0

df.churn.head()
df.churn = (df.churn == 'yes').astype(int)
df.churn
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: churn, Length: 7043, dtype: int64

# %% [markdown]
# ## Validation

# %%
from sklearn.model_selection import train_test_split

# %%
# Split the data into training and testing sets
df_full_train, df_test = train_test_split(df, test_size = 0.2, random_state = 1)

# %%
# Split data into training and validation sets
df_train, df_val = train_test_split(df_full_train, test_size = 0.25, random_state = 1)

# %%
# Assaing y values
y_train = df_train.churn.values
y_val = df_val.churn.values
y_test = df_test.churn.values

# %%
# Delete target variable from dataset
del df_train['churn']   
del df_val['churn']
del df_test['churn']

# %% [markdown]
# ## EDA

# %%
df_full_train
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 1814  5442-pptjy    male              0     yes        yes      12
# 5946  6261-rcvns  female              0      no         no      42
# 3881  2176-osjuv    male              0     yes         no      71
# 2389  6161-erdgd    male              0     yes        yes      71
# 3676  2364-ufrom    male              0      no         no      30
# ...          ...     ...            ...     ...        ...     ...
# 905   0781-lkxbr    male              1      no         no       9
# 5192  3507-gasnp    male              0      no        yes      60
# 3980  8868-wozgu    male              0      no         no      28
# 235   1251-krreg    male              0      no         no       2
# 5157  5840-nvdcg  female              0     yes        yes      16
#
#      phoneservice multiplelines internetservice       onlinesecurity  ...  \
# 1814          yes            no              no  no_internet_service  ...
# ...

# %%
# Check for nulls
df_full_train.isnull().sum()
# Out:
# customerid          0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# dtype: int64

# %%
#Access the target variable
df_full_train.churn.value_counts()
global_churn_rate = df_full_train.churn.mean()
round(global_churn_rate, 2)
# Out:
# np.float64(0.27)

# %%
# Seperated numerical from categorical columns
df_full_train.dtypes
numerical = ['tenure', 'monthlycharges', 'totalcharges']
categorical = ['gender', 'seniorcitizen', 'partner', 'dependents',
     'phoneservice', 'multiplelines', 'internetservice',
       'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
       'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
       'paymentmethod']

# %%
# unique values per collumn

df_full_train[categorical].nunique()
# Out:
# gender              2
# seniorcitizen       2
# partner             2
# dependents          2
# phoneservice        2
# multiplelines       3
# internetservice     3
# onlinesecurity      3
# onlinebackup        3
# deviceprotection    3
# techsupport         3
# streamingtv         3
# streamingmovies     3
# contract            3
# paperlessbilling    2
# paymentmethod       4
# dtype: int64

# %% [markdown]
# # Feature Importance

# %%
df_full_train.head()
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 1814  5442-pptjy    male              0     yes        yes      12
# 5946  6261-rcvns  female              0      no         no      42
# 3881  2176-osjuv    male              0     yes         no      71
# 2389  6161-erdgd    male              0     yes        yes      71
# 3676  2364-ufrom    male              0      no         no      30
#
#      phoneservice multiplelines internetservice       onlinesecurity  ...  \
# 1814          yes            no              no  no_internet_service  ...
# 5946          yes            no             dsl                  yes  ...
# 3881          yes           yes             dsl                  yes  ...
# 2389          yes           yes             dsl                  yes  ...
# 3676          yes            no             dsl                  yes  ...
#
#          deviceprotection          techsupport          streamingtv  \
# ...

# %%
# Female churn rate
churn_female = df_full_train[df_full_train['gender'] == 'female'].churn.mean()
churn_female
# Out:
# np.float64(0.27682403433476394)

# %%
# Male churn rate
churn_male = df_full_train[df_full_train['gender'] == 'male'].churn.mean()
churn_male
# Out:
# np.float64(0.2632135306553911)

# %%
df_full_train.partner.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 1814    yes
# 5946     no
# 3881    yes
# 2389    yes
# 3676     no
#        ...
# 905      no
# 5192     no
# 3980     no
# 235      no
# 5157    yes
# Name: partner, Length: 5634, dtype: str>

# %%
# Churn rate for customers with a partner
churn_partner = df_full_train[df_full_train['partner'] == 'yes'].churn.mean()
churn_partner
# Out:
# np.float64(0.20503330866025166)

# %%
# Churn rate for customers without a partner
churn_no_partner = df_full_train[df_full_train['partner'] == 'no'].churn.mean()
churn_no_partner
# Out:
# np.float64(0.3298090040927694)

# %% [markdown]
# Differnce

# %%
global_churn_rate - churn_partner
# Out:
# np.float64(0.06493474245795922)

# %%
global_churn_rate - churn_no_partner
# Out:
# np.float64(-0.05984095297455855)

# %%
global_churn_rate - churn_female
# Out:
# np.float64(-0.006855983216553063)

# %%
global_churn_rate - churn_male
# Out:
# np.float64(0.006754520462819769)

# %% [markdown]
# partner variable is more important for churn rate than gender

# %% [markdown]
# Risk Ratio

# %%
global_churn_rate / churn_partner #More likely to churn
# Out:
# np.float64(1.3167033828906243)

# %%
global_churn_rate / churn_no_partner # less likely to churn
# Out:
# np.float64(0.8185587651278121)

# %%
from IPython.display import display

# %% [markdown]
# calculating churn

# %%
for c in categorical:
    print(c)
    df_group = df_full_train.groupby(c).churn.agg(['mean', 'count'])
    df_group['diff'] = df_group['mean'] - global_churn_rate
    df_group['risk'] = df_group['mean'] / global_churn_rate
    display(df_group)
    print()
    print()
# Out:
# gender
#             mean  count      diff      risk
# gender
# female  0.276824   2796  0.006856  1.025396
# male    0.263214   2838 -0.006755  0.974980
# seniorcitizen
#                    mean  count      diff      risk
# seniorcitizen
# 0              0.242270   4722 -0.027698  0.897403
# 1              0.413377    912  0.143409  1.531208
# partner
#              mean  count      diff      risk
# partner
# no       0.329809   2932  0.059841  1.221659
# yes      0.205033   2702 -0.064935  0.759472
# dependents
#                 mean  count      diff      risk
# dependents
# no          0.313760   3968  0.043792  1.162212
# yes         0.165666   1666 -0.104302  0.613651
# phoneservice
#                   mean  count      diff      risk
# phoneservice
# no            0.241316    547 -0.028652  0.893870
# yes           0.273049   5087  0.003081  1.011412
# multiplelines
#                       mean  count      diff      risk
# multiplelines
# ...

# %% [markdown]
# ### Mutual Information (categorical column importance) - tells you how important each variable is. Tells us how much we can learn about one variable if we know the value of another

# %%
from sklearn.metrics import mutual_info_score

# %%
mutual_info_score(df_full_train.churn, df_full_train.contract)
# Out:
# 0.0983203874041556

# %%
mutual_info_score(df_full_train.churn, df_full_train.gender)
# Out:
# 0.0001174846211139946

# %%
mutual_info_score(df_full_train.churn, df_full_train.partner)
# Out:
# 0.009967689095399745

# %%
# Create function for mutual_info since apply only takes one argument

def mutual_info_churcn_score(series):
    return mutual_info_score(series, df_full_train.churn)

# Use apply function

mi= df_full_train[categorical].apply(mutual_info_churcn_score) #iterates through every column in categorical and applies mutual_info_churn_score function to it
mi.sort_values(ascending=False)
# Out:
# contract            0.098320
# onlinesecurity      0.063085
# techsupport         0.061032
# internetservice     0.055868
# onlinebackup        0.046923
# deviceprotection    0.043453
# paymentmethod       0.043210
# streamingtv         0.031853
# streamingmovies     0.031581
# paperlessbilling    0.017589
# dependents          0.012346
# partner             0.009968
# seniorcitizen       0.009410
# multiplelines       0.000857
# phoneservice        0.000229
# gender              0.000117
# dtype: float64

# %% [markdown]
# ## Correlation (numerical value importance)

# %%
df_full_train[numerical].corrwith(df_full_train.churn)
# when tenure increases, churn rate goes down
# when monthly charges increase, churn rate goes up
# when total charges increase, churn rate goes down
# tenure and total charges are correlated (that's why they are both negatively correlated with churn)
# Out:
# tenure           -0.351885
# monthlycharges    0.196805
# totalcharges     -0.196353
# dtype: float64

# %% [markdown]
# Tenure

# %%
df_full_train[df_full_train.tenure <=2].churn.mean()
# Out:
# np.float64(0.5953420669577875)

# %%
df_full_train[(df_full_train.tenure > 2) & (df_full_train.tenure <=12)].churn.mean()
# Out:
# np.float64(0.3994413407821229)

# %%
df_full_train[df_full_train.tenure > 12].churn.mean()
# Out:
# np.float64(0.17634908339788277)

# %% [markdown]
# monthlycharges

# %%
df_full_train[df_full_train.monthlycharges <=20].churn.mean()
# Out:
# np.float64(0.08795411089866156)

# %%
df_full_train[(df_full_train.tenure > 20) & (df_full_train.tenure <=50)].churn.mean()
# Out:
# np.float64(0.2147165259348613)

# %%
df_full_train[df_full_train.tenure > 50].churn.mean()
# Out:
# np.float64(0.09025270758122744)

# %% [markdown]
# ## One Hot Coding

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
dv = DictVectorizer(sparse=False)

train_dict = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

val_dict = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dict)

# %% [markdown]
# ## Logistic Regression

# %%
def sigmoid(z):
    return 1/()

# %% [markdown]
# ## Training logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.intercept_[0]
# Out:
# np.float64(-0.1109287445794238)

# %%
model.coef_[0].round(3)
# Out:
# array([ 0.564, -0.154, -0.519, -0.013, -0.095,  0.071, -0.098, -0.082,
#        -0.033, -0.076, -0.354,  0.343, -0.098,  0.002, -0.251,  0.162,
#        -0.02 ,  0.066, -0.098, -0.076,  0.251, -0.098, -0.261, -0.228,
#         0.119, -0.121,  0.012, -0.095, -0.03 ,  0.045, -0.028,  0.162,
#        -0.271,  0.221, -0.097, -0.098,  0.087, -0.05 , -0.098,  0.039,
#         0.194, -0.098, -0.205, -0.072,  0.   ])

# %%
model.predict_proba(X_train)
# first column is probability of not churning, second column is probability of churning
# Out:
# array([[0.91088688, 0.08911312],
#        [0.33128828, 0.66871172],
#        [0.36229559, 0.63770441],
#        ...,
#        [0.48776317, 0.51223683],
#        [0.96993479, 0.03006521],
#        [0.2971009 , 0.7028991 ]], shape=(4225, 2))

# %%
y_pred = model.predict_proba(X_val)[:,1]
# Soft prediction for churning, we still need to set a threshold to make it a hard prediction

# %%
churn_decision = y_pred >= 0.5

# %%
df_val[churn_decision].customerid
# These are the customers that we predict will churn based on our model. We can then target these customers with a retention campaign.
# Out:
# 2504    8433-wxgna
# 4597    3440-jpscl
# 2343    2637-fkfsy
# 5591    7228-omtpn
# 4482    6711-fldfb
#            ...
# 2611    5976-jcjrh
# 4211    2034-cgrhz
# 3999    5276-kqwhg
# 6240    6521-yytyi
# 5282    3049-solay
# Name: customerid, Length: 322, dtype: str

# %%
(y_val == churn_decision).mean()
# Out:
# np.float64(0.801277501774308)

# %%
df_pred = pd.DataFrame()
df_pred['probability'] = y_pred
df_pred['prediction'] = churn_decision.astype(int)
df_pred['actual'] = y_val

# %%
df_pred['correct'] = df_pred.prediction == df_pred.actual

# %%
df_pred.correct.mean()
# Out:
# np.float64(0.801277501774308)

# %%
churn_decision.astype(int)
# Out:
# array([0, 0, 0, ..., 0, 1, 1], shape=(1409,))

# %% [markdown]
# ## Model Interpretation

# %%
dict(zip(dv.get_feature_names_out(), model.coef_[0].round(3)))
# create a dict with features and their values
# Out:
# {'contract=month-to-month': np.float64(0.564),
#  'contract=one_year': np.float64(-0.154),
#  'contract=two_year': np.float64(-0.519),
#  'dependents=no': np.float64(-0.013),
#  'dependents=yes': np.float64(-0.095),
#  'deviceprotection=no': np.float64(0.071),
#  'deviceprotection=no_internet_service': np.float64(-0.098),
#  'deviceprotection=yes': np.float64(-0.082),
#  'gender=female': np.float64(-0.033),
#  'gender=male': np.float64(-0.076),
#  'internetservice=dsl': np.float64(-0.354),
#  'internetservice=fiber_optic': np.float64(0.343),
#  'internetservice=no': np.float64(-0.098),
#  'monthlycharges': np.float64(0.002),
#  'multiplelines=no': np.float64(-0.251),
#  'multiplelines=no_phone_service': np.float64(0.162),
#  'multiplelines=yes': np.float64(-0.02),
#  'onlinebackup=no': np.float64(0.066),
#  'onlinebackup=no_internet_service': np.float64(-0.098),
#  'onlinebackup=yes': np.float64(-0.076),
#  'onlinesecurity=no': np.float64(0.251),
# ...
